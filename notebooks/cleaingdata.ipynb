# %%
from datasets import load_dataset
data=load_dataset('FahadIqbal5188/floorplan-SDXL' , split='train')
data
# Out:
# Dataset({
#     features: ['image', 'text'],
#     num_rows: 10965
# })

# %%
data[0]['image']
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1500x1125>

# %%
import os
from tqdm import tqdm

if not os.path.exists('images'):
    os.makedirs('images')

for i in tqdm(range(1628)):
    file_path = f'images/image_{i}.png'
    if not os.path.exists(file_path):  
        data[i]['image'].save(file_path)
# Out:
# 100%|██████████| 1628/1628 [00:00<00:00, 5807.39it/s]

# %%
type(data[0]['image'])
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
import pandas as pd

rows = []
for i in range(1628):
    text_value = data[i]['text']
    if text_value:  
        rows.append({"id": i, "description": text_value})

df = pd.DataFrame(rows)
df.dropna(inplace=True)
df.drop_duplicates(subset="description", inplace=True)


df["image_path"] = [f"images/image_{i}.png" for i in df["id"]]

df.to_csv("cleaned_dataset_part1.csv", index=False)
print("saved cleaned_dataset_part1.csv !")
# Out:
# saved cleaned_dataset_part1.csv !

# %%
if not os.path.exists('images_2'):
    os.makedirs('images_2')

for i in tqdm(range(1628, 3001)):
    file_path = f'images_2/image_{i}.png'
    if not os.path.exists(file_path):  
        data[i]['image'].save(file_path)
# Out:
# 100%|██████████| 1373/1373 [00:00<00:00, 5914.95it/s]

# %%
rows_2 = []
for i in range(1628, 3001):
    text_value = data[i]['text']
    if text_value:
        rows_2.append({"id": i, "description": text_value})

df_2 = pd.DataFrame(rows_2)
df_2.dropna(inplace=True)
df_2.drop_duplicates(subset="description", inplace=True)
df_2["image_path"] = [f"images_2/image_{i}.png" for i in df_2["id"]]

df_2.to_csv("cleaned_dataset_part2.csv", index=False)
print("saved cleaned_dataset_part2.csv !")
# Out:
# saved cleaned_dataset_part2.csv !

# %%
import os
import pandas as pd
from tqdm import tqdm


if not os.path.exists('images_3'):
    os.makedirs('images_3')


for i in tqdm(range(3001, 4501)):
    file_path = f'images_3/image_{i}.png'
    if not os.path.exists(file_path):
        data[i]['image'].save(file_path)
# Out:
# 100%|██████████| 1500/1500 [00:00<00:00, 3795.14it/s]

# %%
rows_3 = []
for i in range(3001, 4501):
    text_value = data[i]['text']
    if text_value:
        rows_3.append({"id": i, "description": text_value})

df_3 = pd.DataFrame(rows_3)
df_3.dropna(inplace=True)
df_3.drop_duplicates(subset="description", inplace=True)


df_3["image_path"] = [f"images_3/image_{i}.png" for i in df_3["id"]]


df_3.to_csv("cleaned_dataset_part3.csv", index=False)
print("saved cleaned_dataset_part3.csv !")
# Out:
# saved cleaned_dataset_part3.csv !

# %%
import os
import pandas as pd
from tqdm import tqdm


if not os.path.exists('images_4'):
    os.makedirs('images_4')


for i in tqdm(range(4501, 6001)):
    file_path = f'images_4/image_{i}.png'
    if not os.path.exists(file_path):
        data[i]['image'].save(file_path)
# Out:
# 100%|██████████| 1500/1500 [00:00<00:00, 2522.33it/s]

# %%
rows_4 = []
for i in range(4501, 6001):
    text_value = data[i]['text']
    if text_value:
        rows_4.append({"id": i, "description": text_value})

df_4 = pd.DataFrame(rows_4)
df_4.dropna(inplace=True)
df_4.drop_duplicates(subset="description", inplace=True)


df_4["image_path"] = [f"images_4/image_{i}.png" for i in df_4["id"]]


df_4.to_csv("cleaned_dataset_part4.csv", index=False)
print("cleaned_dataset_part4.csv !")
# Out:
# cleaned_dataset_part4.csv !

# %%
if not os.path.exists('images_5'):
    os.makedirs('images_5')


for i in tqdm(range(6001, 7501)):
    file_path = f'images_5/image_{i}.png'
    if not os.path.exists(file_path):
        data[i]['image'].save(file_path)
# Out:
# 100%|██████████| 1500/1500 [00:00<00:00, 3338.43it/s]

# %%
rows_5 = []
for i in range(6001, 7501):
    text_value = data[i]['text']
    if text_value:
        rows_5.append({"id": i, "description": text_value})

df_5 = pd.DataFrame(rows_5)
df_5.dropna(inplace=True)
df_5.drop_duplicates(subset="description", inplace=True)


df_5["image_path"] = [f"images_5/image_{i}.png" for i in df_5["id"]]

df_5.to_csv("cleaned_dataset_part5.csv", index=False)
print("saved cleaned_dataset_part5.csv ")
# Out:
# saved cleaned_dataset_part5.csv

# %%
if not os.path.exists('images_6'):
    os.makedirs('images_6')


for i in tqdm(range(7501, 9001)):
    file_path = f'images_6/image_{i}.png'
    if not os.path.exists(file_path):
        data[i]['image'].save(file_path)
# Out:
# 100%|██████████| 1500/1500 [00:00<00:00, 3075.77it/s]

# %%
rows_6 = []
for i in range(7501, 9001):
    text_value = data[i]['text']
    if text_value:
        rows_6.append({"id": i, "description": text_value})

df_6 = pd.DataFrame(rows_6)
df_6.dropna(inplace=True)
df_6.drop_duplicates(subset="description", inplace=True)


df_6["image_path"] = [f"images_6/image_{i}.png" for i in df_6["id"]]


df_6.to_csv("cleaned_dataset_part6.csv", index=False)
print("saved cleaned_dataset_part6.csv !")
# Out:
# saved cleaned_dataset_part6.csv !

# %%
if not os.path.exists('images_7'):
    os.makedirs('images_7')


for i in tqdm(range(9001, 10001)):
    file_path = f'images_7/image_{i}.png'
    if not os.path.exists(file_path):
        data[i]['image'].save(file_path)
# Out:
# 100%|██████████| 1000/1000 [00:00<00:00, 6480.13it/s]

# %%
rows_7 = []
for i in range(9001, 10001):
    text_value = data[i]['text']
    if text_value:
        rows_7.append({"id": i, "description": text_value})

df_7 = pd.DataFrame(rows_7)
df_7.dropna(inplace=True)
df_7.drop_duplicates(subset="description", inplace=True)


df_7["image_path"] = [f"images_7/image_{i}.png" for i in df_7["id"]]


df_7.to_csv("cleaned_dataset_part7.csv", index=False)
print("saved cleaned_dataset_part7.csv !")
# Out:
# saved cleaned_dataset_part7.csv !

# %%
if not os.path.exists('images_8'):
    os.makedirs('images_8')


for i in tqdm(range(10001, 10965)):
    file_path = f'images_8/image_{i}.png'
    if not os.path.exists(file_path):
        data[i]['image'].save(file_path)
# Out:
# 100%|██████████| 964/964 [00:00<00:00, 4188.59it/s]

# %%
rows_8 = []
for i in range(10001, 10965):
    text_value = data[i]['text']
    if text_value:
        rows_8.append({"id": i, "description": text_value})

df_8 = pd.DataFrame(rows_8)
df_8.dropna(inplace=True)
df_8.drop_duplicates(subset="description", inplace=True)


df_8["image_path"] = [f"images_8/image_{i}.png" for i in df_8["id"]]


df_8.to_csv("cleaned_dataset_part8.csv", index=False)
print("Saved cleaned_dataset_part8.csv !")
# Out:
# Saved cleaned_dataset_part8.csv !

# %%
import pandas as pd
import glob


all_files = glob.glob("cleaned_dataset*.csv")


dfs = [pd.read_csv(f) for f in all_files]


final_df = pd.concat(dfs, ignore_index=True)


# final_df.dropna(inplace=True)
# final_df.drop_duplicates(subset="description", inplace=True)


final_df.to_csv("final_dataset.csv", index=False)

print("✅ created final_dataset.csv sucessfully!")
print("total rows:", len(final_df))
# Out:
# ✅ created final_dataset.csv sucessfully!
# total rows: 1605

# %%
vevgv=pd.read_csv("resized_dataset.csv")
vevgv.head()
# Out:
#    id                                        description          image_path  \
# 0   0  bedrooms : 2 | toilet : 2 | attached _ toilet ...  images/image_0.png
# 1   1  bedrooms : 2 | toilet : 2 | attached _ toilet ...  images/image_1.png
# 2   2  bedrooms : 3 | toilet : 3 | attached _ toilet ...  images/image_2.png
# 3   3  bedrooms : 1 | toilet : 2 | attached _ toilet ...  images/image_3.png
# 4   5  bedrooms : 1 | toilet : 2 | attached _ toilet ...  images/image_5.png
#
#                         image
# 0  resized_images\image_0.png
# 1  resized_images\image_1.png
# 2  resized_images\image_2.png
# 3  resized_images\image_3.png
# 4  resized_images\image_5.png

# %%
from PIL import Image
import pandas as pd
import os
from tqdm import tqdm

df = pd.read_csv("final_dataset.csv")
output_folder = "resized_images"
os.makedirs(output_folder, exist_ok=True)

for idx, row in tqdm(df.iterrows(), total=len(df)):
    image_path_2 = row["image_path"]
    image_id = row["id"]

    try:
        new_path = os.path.join(output_folder, f"image_{image_id}.png")
        if os.path.exists(new_path):
            df.at[idx, "image"] = new_path
            continue

        img = Image.open(image_path_2)
        img_resized = img.resize((512, 512))
        img_resized.save(new_path)
        df.at[idx, "image"] = new_path

    except Exception as e:
        print(f"⚠️ حصل خطأ في الصورة {image_path_2}: {e}")

df.to_csv("resized_dataset.csv", index=False)
# Out:
# 100%|██████████| 1605/1605 [00:00<00:00, 12079.09it/s]

# %%
vevgv=pd.read_csv("resized_dataset.csv")
vevgv.head()

vevgv.drop(columns=["image_path"], inplace=True)
vevgv.head()
vevgv.to_csv("resized_dataset.csv", index=False)

# %%
vevgv.head()
# Out:
#    id                                        description  \
# 0   0  bedrooms : 2 | toilet : 2 | attached _ toilet ...
# 1   1  bedrooms : 2 | toilet : 2 | attached _ toilet ...
# 2   2  bedrooms : 3 | toilet : 3 | attached _ toilet ...
# 3   3  bedrooms : 1 | toilet : 2 | attached _ toilet ...
# 4   5  bedrooms : 1 | toilet : 2 | attached _ toilet ...
#
#                         image
# 0  resized_images\image_0.png
# 1  resized_images\image_1.png
# 2  resized_images\image_2.png
# 3  resized_images\image_3.png
# 4  resized_images\image_5.png

# %%
vevgv.rename(columns={
    "description": "Text",
}, inplace=True)
vevgv.to_csv("resized_dataset.csv", index=False)

# %%
import pandas as pd

df = pd.read_csv("resized_dataset.csv")
print(df.columns)
# Out:
# Index(['id', 'Text', 'image'], dtype='object')
